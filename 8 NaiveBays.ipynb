# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
X = df.drop('Species', axis=1)  # Replace 'species' with the actual target column name in your CSV
y = df['Species']

# %%
df.shape
# Out:
# (150, 6)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
# predicts species of unseen test data
y_pred = model.predict(x_test)

# %%
model.score(x,y)
# Out:
# 0.96

# %%
cf = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cf)
# shows how many predicions were correct /incorrect
# Out:
# Confusion Matrix:
#  [[15  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]

# %%
labels = model.classes_
for i, label in enumerate(labels):
    tp = cf[i, i]
    fp = cf[:, i].sum() - tp
    fn = cf[i, :].sum() - tp
    tn = cf.sum() - (tp + fp + fn)
    
    accuracy = (tp + tn) / cf.sum()
    error_rate = 1 - accuracy
    precision = tp / (tp + fp) if (tp + fp) else 0
    recall = tp / (tp + fn) if (tp + fn) else 0

    print(f"\nClass: {label}")
    print(f"TP: {tp}, FP: {fp}, FN: {fn}, TN: {tn}")
    print(f"Accuracy: {accuracy:.2f}")
    print(f"Error Rate: {error_rate:.2f}")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
# Out:
# Class: Iris-setosa
# TP: 15, FP: 0, FN: 0, TN: 23
# Accuracy: 1.00
# Error Rate: 0.00
# Precision: 1.00
# Recall: 1.00
#
# Class: Iris-versicolor
# TP: 11, FP: 0, FN: 0, TN: 27
# Accuracy: 1.00
# Error Rate: 0.00
# Precision: 1.00
# Recall: 1.00
#
# Class: Iris-virginica
# TP: 12, FP: 0, FN: 0, TN: 26
# Accuracy: 1.00
# Error Rate: 0.00
# Precision: 1.00
# Recall: 1.00

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       1.00      1.00      1.00        11
#  Iris-virginica       1.00      1.00      1.00        12
#
#        accuracy                           1.00        38
#       macro avg       1.00      1.00      1.00        38
#    weighted avg       1.00      1.00      1.00        38
